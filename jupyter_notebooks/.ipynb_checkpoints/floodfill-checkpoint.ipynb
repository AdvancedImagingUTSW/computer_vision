# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import filters, morphology
from skimage.io import imread, imsave
from skimage.segmentation import flood, flood_fill
import pyclesperanto_prototype as cle

# %%
cle.select_device()
print("Used GPU: " + cle.get_device().name)
# Out:
# Used GPU: Tesla V100-PCIE-32GB

# %%
im_data = imread('/home2/kdean/Desktop/temp/minimum748447634.tif')
im_data = np.array(im_data)
im_data = np.int8(im_data)

print("Loaded Image Size: " + str(im_data.shape))
# Out:
# Loaded Image Size: (451, 748, 654)

# %%
input = cle.push(im_data)
print("Image size in GPU: " + str(input.shape))
# Out:
# Image size in GPU: (451, 748, 654)

# %%
blurred = cle.gaussian_blur(im_data, image1, 2, 2, 2)
blurred = cle.pull(blurred)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(im_data[224,:,:], cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')
ax[1].imshow(image1[224,:,:], cmap=plt.cm.gray)
ax[1].plot(369, 308, 'ro')  # seed point
ax[1].set_title('Blurred')
ax[1].axis('off')
plt.show()

# %%
# Flood Fill
print(np.shape(blurred))
filled_image = flood_fill(blurred, (369, 308, 224), 255, tolerance=.00000005)

fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(blurred[224,:,:], cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')

ax[1].imshow(filled_image[224,:,:], cmap=plt.cm.gray)
ax[1].plot(369, 308, 'ro')  # seed point
ax[1].set_title('After flood fill')
ax[1].axis('off')

plt.show()
# Out:
# (654, 748, 451)

# %%
imsave("/home2/kdean/Desktop/temp/filled.tif",filled_image)
